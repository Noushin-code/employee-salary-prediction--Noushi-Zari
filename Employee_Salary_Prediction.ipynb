# %% [markdown]
# # Installing packages

# %% [markdown]
# Libraries Overview
# pandas (pd): This library is used for data manipulation and analysis. It provides data structures like DataFrames which are essential for handling tabular data efficiently.
#
# numpy (np): This library is fundamental for numerical computing in Python. It supports large multi-dimensional arrays and matrices, along with a collection of mathematical functions to operate on these arrays.
#
# matplotlib.pyplot (plt): This is a plotting library used for creating static, interactive, and animated visualizations in Python. It is highly customizable and integrates well with other libraries.
#
# seaborn (sns): This statistical data visualization library is built on top of matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics.
#
# warnings: This module is used to handle warnings in Python. The filterwarnings('ignore') function is used here to suppress any warnings that might arise during the execution of our code, ensuring a cleaner output.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Loading Data
#
# **Load the Dataset**: Import the dataset into a pandas DataFrame. <br />
# **View Basic Information**: Get an overview of the dataset, including data types and non-null counts.<br />
# **Preview the Data**: Display the first few rows of the dataset. <br />
# **Check for Missing Values**: Identify columns with missing values and their counts.<br />
# **Summary Statistics**: Obtain summary statistics for numerical columns. <br />
# **Unique Values in Categorical Columns**: View the unique values in specific categorical columns. <br />

# %%
# Dataset Source: https://www.kaggle.com/
df = pd.read_csv(r'C:\Users\Saeed\Downloads\HR_Dataset.csv')

# %% [markdown]
# Basic Data Understanding
#
#
# *   shape
# *   info
# *   describe
# *   duplicate values
# *   null value handling
# *   target column distribution

# %%
df.head(10)
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
# 5                0.41             0.50               2                   153
# 6                0.10             0.77               6                   247
# 7                0.92             0.85               5                   259
# 8                0.89             1.00               5                   224
# 9                0.42             0.53               2                   142
#
#    time_spend_company  Work_accident  left  promotion_last_5years Department  \
# ...

# %%
df.shape
# Out:
# (14999, 10)

# %%
df.isnull().sum()
# Out:
# satisfaction_level       0
# last_evaluation          0
# number_project           0
# average_montly_hours     0
# time_spend_company       0
# Work_accident            0
# left                     0
# promotion_last_5years    0
# Department               0
# salary                   0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 3008

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (11991, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11991 entries, 0 to 11999
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     11991 non-null  float64
#  1   last_evaluation        11991 non-null  float64
#  2   number_project         11991 non-null  int64
#  3   average_montly_hours   11991 non-null  int64
#  4   time_spend_company     11991 non-null  int64
#  5   Work_accident          11991 non-null  int64
#  6   left                   11991 non-null  int64
#  7   promotion_last_5years  11991 non-null  int64
#  8   Department             11991 non-null  object
#  9   salary                 11991 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.0+ MB

# %%
df.columns
# Out:
# Index(['satisfaction_level', 'last_evaluation', 'number_project',
#        'average_montly_hours', 'time_spend_company', 'Work_accident', 'left',
#        'promotion_last_5years', 'Department', 'salary'],
#       dtype='object')

# %%
df['salary'].value_counts()
# Out:
# salary
# low       5740
# medium    5261
# high       990
# Name: count, dtype: int64

# %% [markdown]
# # Data Preprocessing
#
# **Data Preprocessing**: Clean, transform, and encode the dataset to prepare it for analysis and model training.

# %%
# Encode categorical features into numeric labels
from sklearn.preprocessing import LabelEncoder
# Encode categorical features into numeric labels
le = LabelEncoder()
df['salary'] = le.fit_transform(df['salary'])
df['Department'] = le.fit_transform(df['Department'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11991 entries, 0 to 11999
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     11991 non-null  float64
#  1   last_evaluation        11991 non-null  float64
#  2   number_project         11991 non-null  int64
#  3   average_montly_hours   11991 non-null  int64
#  4   time_spend_company     11991 non-null  int64
#  5   Work_accident          11991 non-null  int64
#  6   left                   11991 non-null  int64
#  7   promotion_last_5years  11991 non-null  int64
#  8   Department             11991 non-null  int64
#  9   salary                 11991 non-null  int64
# dtypes: float64(2), int64(8)
# memory usage: 1.0 MB

# %% [markdown]
# # Data Visualizations:
# Marks your creativity to your recruiter

# %%
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                0.38             0.53               2                   157
# 1                0.80             0.86               5                   262
# 2                0.11             0.88               7                   272
# 3                0.72             0.87               5                   223
# 4                0.37             0.52               2                   159
#
#    time_spend_company  Work_accident  left  promotion_last_5years  Department  \
# 0                   3              0     1                      0           7
# 1                   6              0     1                      0           7
# 2                   4              0     1                      0           7
# 3                   5              0     1                      0           7
# 4                   3              0     1                      0           7
#
#    salary
# 0       1
# 1       2
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11991 entries, 0 to 11999
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     11991 non-null  float64
#  1   last_evaluation        11991 non-null  float64
#  2   number_project         11991 non-null  int64
#  3   average_montly_hours   11991 non-null  int64
#  4   time_spend_company     11991 non-null  int64
#  5   Work_accident          11991 non-null  int64
#  6   left                   11991 non-null  int64
#  7   promotion_last_5years  11991 non-null  int64
#  8   Department             11991 non-null  int64
#  9   salary                 11991 non-null  int64
# dtypes: float64(2), int64(8)
# memory usage: 1.0 MB

# %% [markdown]
# Checking for outliers

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %% [markdown]
# Employemnt satisfaction distribution across department

# %%
sns.barplot(x='Department',y='satisfaction_level',data=df)
# Out:
# <Axes: xlabel='Department', ylabel='satisfaction_level'>

# %%
sns.countplot(x='Work_accident',data=df)
# Out:
# <Axes: xlabel='Work_accident', ylabel='count'>

# %%
sns.countplot(x='left',data=df)
# Out:
# <Axes: xlabel='left', ylabel='count'>

# %% [markdown]
# ditribution of time_spent vs promotion in company

# %%
sns.histplot(x='time_spend_company',y='promotion_last_5years',data=df)
# Out:
# <Axes: xlabel='time_spend_company', ylabel='promotion_last_5years'>

# %%
df.groupby(['Department','promotion_last_5years'])['salary'].mean()
# Out:
# Department  promotion_last_5years
# 0           0                        1.366530
#             1                        1.500000
# 1           0                        1.389302
#             1                        1.761905
# 2           0                        1.327332
#             1                        0.900000
# 3           0                        1.379661
#             1                        1.454545
# 4           0                        1.135000
#             1                        0.638889
# 5           0                        1.346749
#             1                        1.555556
# 6           0                        1.348397
# 7           0                        1.371267
#             1                        1.534483
# 8           0                        1.383380
#             1                        1.625000
# 9           0                        1.342484
#             1                        1.590909
# Name: salary, dtype: float64

# %% [markdown]
# average_monthly_hours per depratment

# %%
df.groupby('Department')['average_montly_hours'].mean()
# Out:
# Department
# 0    200.638320
# 1    201.291066
# 2    200.877617
# 3    199.371048
# 4    201.529817
# 5    199.487370
# 6    198.893586
# 7    200.242050
# 8    200.627128
# 9    201.115419
# Name: average_montly_hours, dtype: float64

# %% [markdown]
# salary vs time_spend

# %%
sns.barplot(x='time_spend_company',y='salary',data=df)
# Out:
# <Axes: xlabel='time_spend_company', ylabel='salary'>

# %% [markdown]
# Chacking out maximjm salary for every department

# %%
df.groupby('Department')['salary'].max()
# Out:
# Department
# 0    2
# 1    2
# 2    2
# 3    2
# 4    2
# 5    2
# 6    2
# 7    2
# 8    2
# 9    2
# Name: salary, dtype: int64

# %%
df.salary.unique()
# Out:
# array([1, 2, 0])

# %% [markdown]
# distribution of number_project vs satisfaction

# %%
sns.barplot(x='number_project',y='satisfaction_level',data=df)
# Out:
# <Axes: xlabel='number_project', ylabel='satisfaction_level'>

# %% [markdown]
# distributin of salary vs satisfaction

# %%
plt.figure(figsize=(10,10))
sns.barplot(x='salary',y='satisfaction_level',data=df)
# Out:
# <Axes: xlabel='salary', ylabel='satisfaction_level'>

# %% [markdown]
# Time spend vs satisfaction

# %%
plt.figure(figsize=(12,10))
sns.scatterplot(x='time_spend_company',y='satisfaction_level',data=df,hue='Department')
# Out:
# <Axes: xlabel='time_spend_company', ylabel='satisfaction_level'>

# %% [markdown]
# Department vs satisfaction level

# %%
plt.figure(figsize=(10,10))
sns.violinplot(x='Department',y='satisfaction_level',data=df)
# Out:
# <Axes: xlabel='Department', ylabel='satisfaction_level'>

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),annot=True,cmap='coolwarm',fmt='.2f',linewidths=0.5,linecolor='black')
# Out:
# <Axes: >

# %% [markdown]
# # Feature Split

# %%
X1 = df.drop(['left'],axis=1)
y1 = df['left']

# %% [markdown]
# # Train_test_split

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X1,y1,test_size=0.3,random_state=42)

# %% [markdown]
# # min_max scaling

# %%
# Split dataset into training and test sets
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
X_train_scaled=scaler.fit_transform(X_train)
X_test_scaled=scaler.transform(X_test)

# %% [markdown]
# # Model training

# %% [markdown]
# # Ada Boost classifier

# %% [markdown]
# # Model building

# %%
from sklearn.ensemble import AdaBoostClassifier
ada = AdaBoostClassifier(random_state=42)
ada.fit(X_train_scaled, y_train)
# Out:
# AdaBoostClassifier(random_state=42)

# %% [markdown]
# # Gradient Boost Classifier

# %%
y_pred = ada.predict(X_test_scaled)

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9677598665925514

# %%
from sklearn.ensemble import GradientBoostingClassifier
gbc = GradientBoostingClassifier(random_state=42)
gbc.fit(X_train_scaled, y_train)
# Out:
# GradientBoostingClassifier(random_state=42)

# %%
y_pred2 = gbc.predict(X_test_scaled)

# %%
print("Accuracy:", accuracy_score(y_test, y_pred2))
# Out:
# Accuracy: 0.9799888827126181

# %% [markdown]
# # Naive Bayers classifier

# %%
from sklearn.naive_bayes import GaussianNB
nb = GaussianNB()
nb.fit(X_train_scaled, y_train)
# Out:
# GaussianNB()

# %%
y_pred3 = nb.predict(X_test_scaled)

# %%
print("Accuracy:", accuracy_score(y_test, y_pred3))
# Out:
# Accuracy: 0.8588104502501389

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98      2995
#            1       0.92      0.89      0.90       603
#
#     accuracy                           0.97      3598
#    macro avg       0.95      0.94      0.94      3598
# weighted avg       0.97      0.97      0.97      3598

# %%
print(confusion_matrix(y_test, y_pred))
# Out:
# [[2946   49]
#  [  67  536]]

# %%
print(classification_report(y_test, y_pred2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99      2995
#            1       0.96      0.92      0.94       603
#
#     accuracy                           0.98      3598
#    macro avg       0.97      0.96      0.96      3598
# weighted avg       0.98      0.98      0.98      3598

# %%
print(confusion_matrix(y_test, y_pred2))
# Out:
# [[2971   24]
#  [  48  555]]

# %% [markdown]
# # Ada Boost classifier : Accuracy: 0.967 <br />
# # Gradient Boost classifier: Accuracy: 0.979 <br />
# # Naive Bayes Classifier : Accuracy: 0.858
